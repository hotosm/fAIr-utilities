# %%
# Standard library imports
import os
import time
import warnings
import ultralytics
from ultralytics.data.converter import convert_dota_to_yolo_obb
from ultralytics import YOLO

os.environ.update(os.environ)
os.environ["RAMP_HOME"] = os.getcwd()

warnings.simplefilter(action="ignore", category=FutureWarning)



start_time = time.time()
base_path = f"/tf/ramp-data/sample_2"

model_input_image_path = f"{base_path}/input"
preprocess_output = f"{base_path}/preprocessed"
yolo_data_dir = f"{base_path}/yolo_v11"

# output_model_path,output_model_iou_accuracy = train_yolo(
#     data=f"{base_path}",
#     weights=f"{os.getcwd()}/yolo11n-seg.pt", 
#     # gpu="cpu",
#     epochs=2,
#     batch_size=8, #16,
#     pc=2.0,
#     output_path=yolo_data_dir,
#     dataset_yaml_path=os.path.join(yolo_data_dir,'yolo_dataset.yaml')
# )
# print(output_model_iou_accuracy)

#/tf/ramp-data/sample_2/yolo_v11/checkpoints/yolov11n-seg_sample_2_ep2_bs8_pc2.0/weights/best.pt
convert_dota_to_yolo_obb(yolo_data_dir)

# Create a new YOLO11n-OBB model from scratch
obb_model = YOLO(os.path.join(yolo_data_dir,'yolo11n-obb.yaml'))

# Train the model on the custom dataset
results = obb_model.train(data=os.path.join(yolo_data_dir,'yolo_dataset.yaml'), epochs=2, imgsz=640)
# Out:
# ...
# Processing val images: 100%|██████████| 22/22 [00:00<00:00, 402946.24it/s]
# FileNotFoundErrorTraceback (most recent call last)
# Input In [10], in <cell line: 39>()
#      36 convert_dota_to_yolo_obb(yolo_data_dir)
#      38 # Create a new YOLO11n-OBB model from scratch
# ---> 39 obb_model = YOLO(os.path.join(yolo_data_dir,'yolo11n-obb.yaml'))
#      41 # Train the model on the custom dataset
#      42 results = obb_model.train(data=os.path.join(yolo_data_dir,'yolo_dataset.yaml'), epochs=2, imgsz=640)
#
# File /usr/local/lib/python3.8/dist-packages/ultralytics/models/yolo/model.py:79, in YOLO.__init__(self, model, task, verbose)
#      76     self.__dict__ = new_instance.__dict__
#      77 else:
#      78     # Continue with default YOLO initialization
# ---> 79     super().__init__(model=model, task=task, verbose=verbose)
#      80     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
# ...
